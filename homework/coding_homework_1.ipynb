# %% [markdown]
# <a href="https://colab.research.google.com/github/sofol-bit/LinSofoNEUR265/blob/main/homework/coding_homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Lindsey Sofo
# *Introduction to Neural Data Analysis*
#
# **February 6th, 2026**

# %%
# import matplotlib etc
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# added numpy/matplotlib after readying step 6/11

# %%
# convert csv into data frame

pandas_data1 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'
panda1 = pd.read_csv(pandas_data1)

pandas_data2 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'
panda2= pd.read_csv(pandas_data2)

cell_types
# Out:
#      -70.21126938
# 0      -49.922277
# 1      -75.719394
# 2      -72.368070
# 3      -63.093008
# 4      -75.546930
# ..            ...
# 494    -70.519670
# 495    -69.917476
# 496    -71.446082
# 497    -49.804129
# 498    -54.084279
#
# [499 rows x 1 columns]

# %%
# convert data into list

data1 = panda1.values.tolist()
data2 = panda2.values.tolist()

# %%
#remove brackets from individual data points

data1 = np.squeeze(data1)

data2 = np.squeeze(data2)

# %%
#print length of data 1

print(data1)
# Out:
# [-69.60158234 -76.03420105 -71.16118393 -76.35402679 -70.89105013
#  -64.11880341 -72.8632112  -78.96890068 -55.4531032  -60.98506045
#  -66.61118807 -67.08294233 -73.90523593 -74.63317594 -49.27067811
#  -76.05053997 -65.45417595 -58.53314018 -66.28985665 -64.09106996
#  -71.49303228 -65.11718958 -73.74140637 -74.81462097 -71.32343356
#  -74.46990373 -65.03939126 -71.94757271 -73.42034054 -71.10602856
#  -61.28795481 -73.79654069 -64.48533249 -69.65824959 -73.71225967
#  -85.56860669 -57.49219704 -76.91730436 -62.61127641 -67.08071963
#  -78.45983535 -78.87342682 -76.14055703 -62.40101166 -72.41336346
#  -62.03701146 -63.30990855 -62.02654052 -73.0206111  -63.11713295
#  -70.05060087 -75.7537974  -57.15310111 -72.52368011 -70.86691952
#  -65.435009   -66.87690226 -70.79107895 -71.34088898 -65.70912288
#  -64.45794886 -62.82061958 -65.03326961 -61.37704976 -71.51313705
#  -71.54903143 -83.53790652 -68.49228492 -69.6041454  -62.87747123
# ...

# %%
#print 3rd-6th elements of data2

data2[2:5]
# Out:
# array([-72.36807022, -63.09300825, -75.5469301 ])

# %%
#print second to last and last elements of data1 using negative indexing

data1[-2:]
# Out:
# array([-65.59535842, -75.10678711])

# %%
#check type of data2

type(data2)
# Out:
# numpy.ndarray

# %%
#make histogram of data1

plt.hist(data1)
# Out:
# (array([  3.,   4.,  23.,  77., 125., 107.,  90.,  42.,  21.,   7.]),
#  array([-88.07835484, -84.19758717, -80.31681949, -76.43605182,
#         -72.55528415, -68.67451648, -64.7937488 , -60.91298113,
#         -57.03221346, -53.15144578, -49.27067811]),
#  <BarContainer object of 10 artists>)

# %%
#apply axis labels to data1 hist

plt.xlabel('Resting Membrane Potential')
plt.ylabel('Count')

plt.hist(data1)
# Out:
# (array([  3.,   4.,  23.,  77., 125., 107.,  90.,  42.,  21.,   7.]),
#  array([-88.07835484, -84.19758717, -80.31681949, -76.43605182,
#         -72.55528415, -68.67451648, -64.7937488 , -60.91298113,
#         -57.03221346, -53.15144578, -49.27067811]),
#  <BarContainer object of 10 artists>)

# %%
#create histogram for data2

plt.hist(data2)
# Out:
# (array([  7.,  28., 117., 148.,  96.,  66.,  26.,   6.,   4.,   1.]),
#  array([-85.27155304, -81.26054661, -77.24954018, -73.23853375,
#         -69.22752732, -65.2165209 , -61.20551447, -57.19450804,
#         -53.18350161, -49.17249518, -45.16148875]),
#  <BarContainer object of 10 artists>)

# %%
#add axis labels for data2

plt.xlabel('Resting Membrane Potential')
plt.ylabel('Count')
plt.hist(data2)
# Out:
# (array([  7.,  28., 117., 148.,  96.,  66.,  26.,   6.,   4.,   1.]),
#  array([-85.27155304, -81.26054661, -77.24954018, -73.23853375,
#         -69.22752732, -65.2165209 , -61.20551447, -57.19450804,
#         -53.18350161, -49.17249518, -45.16148875]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# data1 cells have a slightly higher(less negative) resting potenteial than data2 cells

# %%
#combine data1 and data2 into data3, data3 as list

data3 = np.concatenate((data1, data2))
data3
# Out:
# array([-69.60158234, -76.03420105, -71.16118393, -76.35402679,
#        -70.89105013, -64.11880341, -72.8632112 , -78.96890068,
#        -55.4531032 , -60.98506045, -66.61118807, -67.08294233,
#        -73.90523593, -74.63317594, -49.27067811, -76.05053997,
#        -65.45417595, -58.53314018, -66.28985665, -64.09106996,
#        -71.49303228, -65.11718958, -73.74140637, -74.81462097,
#        -71.32343356, -74.46990373, -65.03939126, -71.94757271,
#        -73.42034054, -71.10602856, -61.28795481, -73.79654069,
#        -64.48533249, -69.65824959, -73.71225967, -85.56860669,
#        -57.49219704, -76.91730436, -62.61127641, -67.08071963,
#        -78.45983535, -78.87342682, -76.14055703, -62.40101166,
#        -72.41336346, -62.03701146, -63.30990855, -62.02654052,
#        -73.0206111 , -63.11713295, -70.05060087, -75.7537974 ,
#        -57.15310111, -72.52368011, -70.86691952, -65.435009  ,
#        -66.87690226, -70.79107895, -71.34088898, -65.70912288,
# ...

# %%
data3[-1]
# Out:
# np.float64(-54.08427915)

# %%
#check if value is last of data2

data2[-1]
# Out:
# np.float64(-54.08427915)
