# %% [markdown]
# <a href="https://colab.research.google.com/github/sofol-bit/LinSofoNEUR265/blob/main/homework/coding_homework_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Lindsey Sofo
# *Introduction to Neural Data Analysis*
#
# **April 2nd, 2026**

# %%
#import modules

import numpy as np
import matplotlib.pyplot as plt

# %%
#import data as numpy arrays

spikes_left_trial1 = np.loadtxt('https://raw.githubusercontent.com/sofol-bit/LinSofoNEUR265/refs/heads/main/data/spikes_left_trial1.csv', delimiter = ',')
spikes_left_trial2 = np.loadtxt('https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/spikes_left_trial2.csv', delimiter = ',')
spikes_right_trial1 = np.loadtxt('https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/spikes_right_trial1.csv', delimiter = ',')
spikes_right_trial2 = np.loadtxt('https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/spikes_right_trial2.csv', delimiter = ',')

# %%
#determine legnth

print(len(spikes_left_trial1))
print(len(spikes_right_trial1))
print(len(spikes_left_trial2))
print(len(spikes_right_trial2))
# Out:
# 65
# 45
# 53
# 69

# %%
#determine firing rate

FR_left1 = print((len(spikes_left_trial1))/30)
FR_right1 = print((len(spikes_right_trial1))/30)
FR_left2 = print((len(spikes_left_trial2))/30)
FR_right2 = print((len(spikes_right_trial2))/30)
# Out:
# 2.1666666666666665
# 1.5
# 1.7666666666666666
# 2.3

# %% [markdown]
# in trail 1, left had higher fr, reversefd for tiral 2
# overall higher FR for trial 2

# %%
#subplots

fig, axes = plt.subplots(1, 2)


axes[0].scatter(spikes_left_trial1, [1]*len(spikes_left_trial1), color = 'red')
axes[0].scatter(spikes_right_trial1, [0]*len(spikes_right_trial1), color = 'blue')
axes[0].set_xlabel('Time')
axes[0].set_ylabel('Spikes')
axes[0].set_title('Trial 1')

axes[1].scatter(spikes_left_trial2, [1]*len(spikes_left_trial2), color = 'red')
axes[1].scatter(spikes_right_trial2, [0]*len(spikes_right_trial2), color = 'blue')
axes[1].set_xlabel('Time')
axes[1].set_ylabel('Spikes')
axes[1].set_title('Trial 2')
# Out:
# Text(0.5, 1.0, 'Trial 2')

# %% [markdown]
# trial 1: seem a bit more equal,  left may be a bit more bursty
# trial 2: right firers more and seems to be more regular

# %%
#ISI calcs

isi_left_trial1 = np.diff(spikes_left_trial1)
isi_right_trial1 = np.diff(spikes_right_trial1)
isi_left_trial2 = np.diff(spikes_left_trial2)
isi_right_trial2 = np.diff(spikes_right_trial2)

# %%
#hists

fig, axes = plt.subplots(1, 4, figsize=(20, 6))
bins = np.arange(0, 2.01, 0.01)

axes[0].hist(isi_left_trial1, bins=bins, color='blue')
axes[0].set_title('ISI left 1')
axes[0].set_xlabel('ISI')
axes[0].set_ylabel('Count')

axes[1].hist(isi_right_trial1, bins=bins, color='pink')
axes[1].set_title('ISI right 1')
axes[1].set_xlabel('ISI')
axes[1].set_ylabel('Count')

axes[2].hist(isi_left_trial2, bins=bins, color='blue')
axes[2].set_title('ISI left 2')
axes[2].set_xlabel('ISI')
axes[2].set_ylabel('Count')

axes[3].hist(isi_right_trial2, bins=bins, color='pink')
axes[3].set_title('ISI right 2')
axes[3].set_xlabel('ISI')
axes[3].set_ylabel('Count')

plt.show()

# %% [markdown]
# overall pretty bursty, may be slightly moreso for left but hard to tell

# %%
#firing rate over time

fr_left1 = np.histogram(spikes_left_trial1, bins2)[0]
fr_right1 = np.histogram(spikes_right_trial1, bins2)[0]
fr_left2 = np.histogram(spikes_left_trial2, bins2)[0]
fr_right2 = np.histogram(spikes_right_trial2, bins2)[0]

fig, ax = plt.subplots(2, 1, figsize=(10, 8))

ax[0].plot(bins2[:-1] + 0.5, fr_left1, color='red', label='Left')
ax[0].plot(bins2[:-1] + 0.5, fr_right1, color='blue', label='Right')
ax[0].set_title('FR across time Trial 1')
ax[0].set_ylabel('FR)')
ax[0].legend()

ax[1].plot(bins2[:-1] + 0.5, fr_left2, color='red', label='Left')
ax[1].plot(bins2[:-1] + 0.5, fr_right2, color='blue', label='Right')
ax[1].set_title('FR across time Trial 2')
ax[1].set_xlabel('Time')
ax[1].set_ylabel('FR')
ax[1].legend()

plt.show()

# %% [markdown]
# seems to be higher overall fr in trial 1 than 2, prefrence for left in trial 1 and right in trial 2
